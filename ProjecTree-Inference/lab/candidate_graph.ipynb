# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from app.agents.enums import NodeType
from app.agents.candidates.graph import candidate_graph
from langchain_teddynote.graphs import visualize_graph

visualize_graph(candidate_graph, xray=True)

# %%
from app.core.log import langfuse_handler
#하위 정보들은 메인그래프에 통합될 경우 이전스테이트 에서 넘어오고
#만약 별도의 api에서 호출될 경우 서비스 단에서 조회하여 전달
candidate = candidate_graph.invoke({
    "current_node_id": 1,
    "current_node_type": "PROJECT",
    "service_type": "APP",
    "current_node_name": """
    여행 도우미 서비스: Urabi
    """,
    "current_node_description": """
    여행은 함께할 때 더 즐겁습니다.
    그러나 예산과 일정이 서로 다른 유럽 여행자들은 홀로 여행하는 경우가 많아, 외로움과 안전에 대한 불안감을 느낍니다.
    Urabi는 이러한 여행자들이 장기 동행과 번개 모임을 통해 믿을 수 있는 동행자를 찾고, 숙소 후기와 여행 물품을 공유하며
    더 안전하고 편리한 여행을 즐길 수 있도록 돕는 지도 기반 여행 동행 & 커뮤니티 플랫폼입니다​

    기획 의도
    💡 유럽 여행자들의 외로움과 안전 문제를 해결하고, 비슷한 여행 스타일을 가진 사람들과 연결될 수 있도록 돕는 서비스입니다.
    💡 장기 동행뿐만 아니라, 즉흥적인 번개 모임 기능을 통해 짧은 시간 함께할 여행자를 찾을 수 있습니다.
    💡 한국인의 믿을 수 있는 숙소 후기와 여행 중 필요 없는 물품 교환·판매 기능을 제공하여,
        유럽 여행 중 발생할 수 있는 여러 불편함을 해결하고자 했습니다.
    💡 지도를 기반으로 한 커뮤니티 결합이라는 차별점으로, 직관적이고 효율적인 여행자 연결을 목표로 합니다.
    """,
    "candidate_count": 3
}, config={
    "callbacks": [langfuse_handler]
})

# %%
for cand in candidate["candidates"].candidates:
    for k, v in cand:
        print(f" {k}: {v} ")
# Out:
#  name: [매칭 시스템] 위치 기반 동행 매칭 및 일정 싱크
#  description: 사용자들이 지도를 통해 근처 또는 동일 경로의 여행자를 발견하고, 장기 동행 또는 번개 모임을 쉽게 제안/수락할 수 있도록 위치 기반 매칭과 일정 동기화 기능을 구현합니다. 이 에픽은 위치 필터(도시/반경), 여행 일정 입력 및 비교, 매칭 제안 알고리듬(거리·일정·여행스타일 기반)과 매칭 요청/수락 플로우를 포함합니다.
#  summary: 지도를 활용해 근처/동일 경로 여행자를 찾아 장기 동행과 번개 모임 매칭을 돕습니다.
#  name: [커뮤니티 시스템] 지도 연동 모임 생성 및 탐색
#  description: 사용자가 지도를 기반으로 번개 모임이나 소규모 이벤트를 생성하고, 위치 중심으로 참여자를 모집/탐색할 수 있게 하여 즉석 만남·지역별 커뮤니티 활성화를 촉진합니다. 이 에픽은 모임 생성(장소·시간·인원), 모임 목록/지도 뷰, 참여 신청 및 취소, 모임 검색(태그/거리/시간 필터) 기능을 포함합니다.
#  summary: 지도를 기반으로 번개 모임을 생성하고 참여자를 모집하는 위치 중심 커뮤니티 기능을 제공합니다.
#  name: [거래·후기 시스템] 숙소 후기 및 여행물품 거래 마켓
#  description: 한국인 여행자 대상의 신뢰할 수 있는 숙소 후기 공유와 여행 중 불필요한 물품의 교환·판매를 지원하여 이용자 편의성과 체류 만족도를 높입니다. 이 에픽은 후기 작성·평점 시스템, 후기 검증(사진·방문 날짜), 마켓 게시글(판매/교환), 메시지 문의 및 거래 상태 관리 기능을 포함합니다.
#  summary: 신뢰 가능한 숙소 후기와 여행물품 교환·판매 기능으로 여행자의 불편을 해소합니다.

# %%
from app.core.log import langfuse_handler
#하위 정보들은 메인그래프에 통합될 경우 이전스테이트 에서 넘어오고
#만약 별도의 api에서 호출될 경우 서비스 단에서 조회하여 전달
candidate_graph.invoke({
    "current_node_id": 4,
    "current_node_type": "TASK",
    "current_node_name": """
    [FE] Google Maps Places API 연동 및 데이터 파싱
    """,
    "current_node_description": """
    - Places Search API를 이용한 주변 상권 정보 수집
    - 영업 시간 및 별점 데이터 DB 매핑
    """
}, config={
    "callbacks": [langfuse_handler]
})
# Out:
# {'feedback': '검증 통과 (점수: 8/10)',
#  'retry_count': 0,
#  'is_valid': True,
#  'current_node_id': 4,
#  'current_node_type': 'TASK',
#  'candidates': CandidateList(candidates=[Candidate(name='[Test] Places API 데이터 파싱 유닛 테스트 작성', description='## 목표\nPlaces Search 및 Place Details 응답을 모사한 목(mock) 데이터를 사용해 파싱 로직의 성공/실패 케이스를 검증합니다. 잘못된 스키마(누락된 필드, 잘못된 타입), 시간대/영업시간 포맷 변이, 별점(평균/리뷰 수)이 비어있거나 0일 때의 처리를 포함해 테스트합니다.\n\n## 가이드\n- Jest (또는 사용 중인 테스트 프레임워크)로 각 파서 함수(parsePlace, parseOpeningHours 등)의 단위 테스트를 작성하세요.\n- HTTP 호출을 실제로 하지 않도록 API 응답을 목킹하고, edge case 케이스(부분 응답, null 필드)를 추가하세요.\n- 파싱 결과가 DB 매핑 스키마(예: open_hours: array, rating: number|null, review_count: number)와 일치하는지 검증하세요.', summary='Places API 응답 파싱 로직에 대한 단위 테스트 작성'), Candidate(name='[Performance] Places API 호출 및 DB 저장 배치화 및 캐싱', description='## 목표\n대량 장소 수집 시 API 호출 비용과 DB 쓰기 부하를 줄이고 응답 속도를 개선합니다.\n\n## 가이드\n- Places Search 결과를 페이지 단위로 가져온 뒤, DB에 한 건씩 저장하지 말고 배치(예: bulk insert)를 사용하세요.\n- 동일 장소 재요청을 줄이기 위해 장소 ID 기반 로컬 캐시(메모리 또는 Redis)를 도입해 최근 처리한 장소는 일정 TTL 동안 스킵하거나 업데이트만 수행합니다.\n- 병렬 호출 시 Rate Limit를 준수하기 위해 간단한 토큰 버킷(throttler)이나 지수 백오프 로직을 추가하세요.\n- 기대 효과: API 호출 횟수 30~70% 감소(캐시 히트에 따라), DB 쓰기 성능/응답 시간 개선(대량 삽입 시 수 ms → 수십 ms 단축).', summary='대량 수집 시 배치 저장과 캐싱으로 호출/DB 부하 최적화'), Candidate(name='[Stability] 영업시간·타임존 파싱 및 예외 처리 강화', description='## 목표\n다양한 영업시간 표현과 타임존 차이로 인한 잘못된 매핑을 방지하고, 부분 정보(휴무일, 24시간 등) 처리 로직을 견고하게 합니다.\n\n## 가이드\n- Places API의 opening_hours, weekday_text, periods 필드를 표준화된 내부 모델(예: [{day:0-6, open:HH:mm, close:HH:mm, is_24h:bool}])로 변환하는 유틸 함수를 만들고, 타임존 정보(place.utc_offset 또는 지오코딩으로 획득)를 반영하세요.\n- 비정상 포맷(예: "Open ⋅ Closes 1\u202fAM")이나 로컬 언어 포맷에 대비한 파서/정규표현식 예외 처리를 추가하세요.\n- 파싱 실패 시 안전한 기본값(예: 영업시간 미등록 상태)으로 DB에 저장하고, 문제 레코드를 로그/모니터링(또는 별도 테이블) 대상으로 표시하세요.\n- 기대 효과: 잘못된 시간 계산으로 인한 잘못된 영업상태 표시 감소, 운영 이슈 탐지 시간 단축.', summary='영업시간과 타임존 파싱의 안정성 강화 및 실패 대응 정책 수립')]),
#  'current_node_name': '\n    [FE] Google Maps Places API 연동 및 데이터 파싱\n    ',
#  'current_node_description': '\n    - Places Search API를 이용한 주변 상권 정보 수집\n    - 영업 시간 및 별점 데이터 DB 매핑\n    ',
#  'sibling_context': ''}

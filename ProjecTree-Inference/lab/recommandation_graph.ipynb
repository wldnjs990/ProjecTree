# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from app.agents.graph import builder, recommend_graph
from app.core.log import langfuse_handler

output = recommend_graph.invoke({
    "current_node_type": "Task",
    "node_name": "[BE] 인증 로직 구현",
    "node_description": "백엔드에서 사용자 로그인을 위한 인증로직을 구현합니다."
},config={"callbacks": [langfuse_handler]})
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 126, 'prompt_tokens': 2876, 'total_tokens': 3002, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '60b1b7db-e23e-40cb-a0bd-46057088a401', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bd566-f84d-73c1-af01-61f59f0f05d3-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '최신 프론트엔드 기술', 'search_depth': 'advanced', 'topic': 'general'}, 'id': 'aaf2501c-2705-4c76-ac3f-a12470733fda', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2876, 'output_tokens': 126, 'total_tokens': 3002, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {
# ...

# %%
output

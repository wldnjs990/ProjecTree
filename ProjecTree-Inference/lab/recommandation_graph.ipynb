# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from app.agents.graph import builder, recommend_graph
from app.core.log import langfuse_handler

output = recommend_graph.invoke({
    "current_node_type": "Task",
    "node_name": "[BE] 인증 로직 구현",
    "node_description": "백엔드에서 사용자 로그인을 위한 인증로직을 구현합니다."
},config={"callbacks": [langfuse_handler]})
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 125, 'prompt_tokens': 2877, 'total_tokens': 3002, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '6c64498d-40e7-468b-af70-8d9d6f952e0f', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bd506-6434-7f42-a854-eef1856016bc-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '최신 프론트엔드 기술', 'search_depth': 'advanced', 'topic': 'general'}, 'id': '7d21b072-66db-42d3-bbec-e24fc03cdaa6', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2877, 'output_tokens': 125, 'total_tokens': 3002, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query": "최신 프론트엔드 기술", "response_time": 3.03, "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://kernel.fastcampus.co.kr/insight_FEtrend2", "title": "예비 프론트엔드 개발자를 위한 최신 기술 트렌드와 2025년 전망", "content": "④ 2025년 프론트엔드 전망: 더욱 깊어지는 기술과 확장되는 가능성\\n\\n2025년, 프론트엔드 개발은 더욱 빠르게 변화하며 새로운 가능성을 열어갈 것으로 예상돼요. 앞서 언급한 2024년 트렌드가 더욱 심화되고, 새로운 기술이 등장하면서 프론트엔드 개발의 지형도를 바꾸게 될 거예요. 그중에서도 중요한 핵심 키워드를 소개합니다.   \\n  \\n 핵심 키워드:   \\n॰ AI와의 융합: AI는 프론트엔드 개발의 모든 영역에 깊숙이 스며들어, 더욱 스마트하고 개인화된 사용자 경험을 제공할 거예요.   \\n  \\n॰ 메타버스: 가상 세계 구축을 위한 프론트엔드 기술이 더욱 발전하면서, 현실과 가상의 경계를 허무는 새로운 사용자 인터페이스가 등장할 것입니다.   \\n  \\n॰ 지속 가능한 개발: 환경 문제에 대한 인식이 높아지면서, 웹 개발에서도 지속 가능한 개발 방식이 더욱 강조될 거예요.   \\n  \\n॰ \\\\\\\\WebAssembly의 성장: 웹 어셈블리는 웹에서 고성능 애플리케이션 개발을 가능하게 하며, 게임, 3D 그래픽 등 다양한 분야에서 활용될 수 있어요.   \\n  \\n॰ 프레임워크 및 라이브러리의 발전: \\\\\\\\SvelteKit, \\\\\\\\SolidStart 등 기존 프레임워크의 단점을 보완하고 새로운 기능을 제공하는 프레임워크가 등장합니다. 다양한 디자인 시스템과 컴포넌트 라이브러리도 계속해서 등장해 개발 생산성을 높여줄 거예요.\\n\\n출처: Adobe stock\\n\\n2. 프론트엔드 개발자, 2024년 트렌드와 2025년 전망을 아우르는 공부전략 [...] 핵심은 자신만의 강점을 보여주고, 프로젝트를 통해 무엇을 배웠는지 명확하게 전달하는 것입니다. 좀 더 구체적인 포트폴리오 제작 가이드는 \'포트폴리오 제작 가이드\' 콘텐츠를 참고할 수 있어요.\\n결론적으로, 프론트엔드 개발은 기술의 발전과 함께 끊임없이 변화하고 있어요. 인공지능, 엣지 컴퓨팅, React 서버 컴포넌트와 같은 최신 기술들을 이해하고 활용하는 것은 개발자 개인의 성장뿐만 아니라 사용자에게 더욱 혁신적인 경험을 제공하는 중요한 요소예요. 웹 개발의 기초부터 비전공자 혹은 실전에 맞는 개발을 고민하는 초보 개발자들 모두 핵심 기술의 습득과 꾸준한 실습, 그리고 포트폴리오를 통해 자신만의 강점을 부각시키는 노력이 필요합니다.   \\n  \\n특히 \'우아한형제들 기술이사 김민태의 데브캠프\' 강좌는 비전공자로 시작해 프론트엔드 개발 그룹장을 맡았던 김민태 강사와 함께할 수 있다는 장점이 있습니다. 김민태 강사는 2013년 5월 60만 명이던 방문자를 2023년 12월 1,900만 명까지 끌어올린 경험이 있으며, 11년 차 개발 교육자로서 1,500명 이상의 주니어 개발자를 교육한 베테랑 강사입니다.  \\n  \\n프론트엔드 개발 시장은 아직도 많은 수요와 성공 가능성을 가진 무대예요. 중요한 것은 빠르게 변하는 기술 흐름 속에서 지속적으로 배우고 성장하려는 자세입니다. 이 과정을 통해 독창성과 문제 해결 능력을 갖춘 프론트엔드 개발자로 자리매김할 수 있을 거예요. [...] 사진: Pixabay\\n\\n2024년의 프론트엔드 개발은 사용자 경험 향상, 개발 생산성 증대, 그리고 새로운 기술 도입이라는 세 가지 큰 흐름 속에서 빠르게 변화하고 있어요. 특히 인공지능, 증강현실 등의 기술이 웹 어플리케이션에도 도입되면서 프론트엔드 개발도 더욱 빠르게 진화하고 있답니다.\\n  \\n  \\n이러한 기술들은 몰입감 있는 사용자 경험을 주도하게 되며, 프론트엔드 개발자는 사용자들에게 최적의 경험을 제공하기 위해 이런 새로운 기술들을 충분히 활용할 수 있어야 해요. 이번 글에서는 최근 주요한 프론트엔드 기술 트렌드를 자세히 살펴보고, 2025년의 프론트엔드 전망을 통해 예비 프론트엔드 개발자로서 성공하는 방법을 소개하려고 합니다.\\n\\n1. 예비 프론트엔드 개발자를 위한 최신 기술 트렌드와 2025년 전망\\n\\n2024년 프론트엔드 개발의 주요 기술 스택을 살펴보면서, 2025년 개발 트렌드 전망도 알아보겠습니다. 주요 프론트엔드 기술 스택 중 큰 자리를 차지하는 세 가지 기술인 React 서버 컴포넌트, 엣지 컴퓨팅, AI 기반 웹 개발을 소개할게요.\\n\\n➀ React 서버 컴포넌트: 서버 측 렌더링의 새로운 패러다임", "score": 0.99958915, "raw_content": null}, {"url": "https://brunch.co.kr/@9bed687d4672454/69", "title": "놓치면 안되는 2025 프론트엔드 개발트렌드 총정리 - 브런치", "content": "마이크로 프론트엔드, JAMstack, 웹 컴포넌트, AI와 머신러닝, 서버리스 아키텍처와 같은 최신 기술들은 앞으로의 프론트엔드 개발에서 중요한 트렌드로", "score": 0.99937856, "raw_content": null}, {"url": "https://pingfanzhilu.tistory.com/entry/2025%EB%85%84-%ED%94%84%EB%A1%A0%ED%8A%B8%EC%97%94%EB%93%9C-%ED%8A%B8%EB%A0%8C%EB%93%9C-%EC%B5%9C%EC%8B%A0-%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%EC%99%80-%ED%94%84%EB%A0%88%EC%9E%84%EC%9B%8C%ED%81%AC-%EB%B9%84%EA%B5%90", "title ...
# techs=[TechRecommandation(id=1, name='react-js', advantage='빠른 개발과 성능 최적화', disadvantage='학습 곡선이 가파름', description='React는 사용자 인터페이스를 구축하기 위한 JavaScript 라이브러리로, 컴포넌트 기반 아키텍처와 가상 DOM을 활용하여 효율적인 렌더링을 제공합니다.', recommendation_score=5, tech_type='FE'), TechRecommandation(id=2, name='edge-computing', advantage='빠른 응답 시간과 데이터 처리', disadvantage='보안 및 관리의 복잡성', description='엣지 컴퓨팅은 데이터 처리와 분석을 네트워크의 가장자리에서 수행하여 지연 시간을 줄이고 성능을 향상시킵니다.', recommendation_score=4, tech_type='BE'), TechRecommandation(id=3, name='ai', advantage='자동화 및 예측 분석', disadvantage='데이터 편향 및 윤리적 문제', description='인공지능은 기계 학습 알고리즘을 활용하여 데이터에서 학습하고 예측을 수행하는 기술입니다.', recommendation_score=5, tech_type='FE')] compairson='React는 빠른 개발과 성능 최적화를 제공하며, 엣지 컴퓨팅은 빠른 응답 시간과 데이터 처리를 가능하게 합니다. AI는 자동화 및 예측 분석을 통해 프론트엔드 개발에 혁신을 가져올 수 있습니다.'
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 120, 'prompt_tokens': 2872, 'total_tokens': 2992, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'solar-mini-250422', 'system_fingerprint': None, 'id': '28d273b1-a1d9-4707-b8b7-84511ec3c3e2', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bd506-642c-7261-a254-a166b6f95051-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '최신 백엔드 기술', 'search_depth': 'advanced', 'topic': 'general'}, 'id': '12b4922f-515a-4fc1-9c06-dfb5bbe023a5', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2872, 'output_tokens': 120, 'total_tokens': 2992, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{"query": "최신 백엔드 기술", "response_time": 3.16, "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://kr.linkedin.com/pulse/top-backend-technologies-2025-choosing-right-stack-your-pmikf?tl=ko", "title": "2025년 최고의 백엔드 기술: 앱에 적합한 스택 선택 - LinkedIn", "content": "### 엔터프라이즈급 애플리케이션을 지원하는 2025년 최고의 백엔드 기술\\n\\n2025년을 맞이하면서 여러 백엔드 기술이 기업 개발을 주도하고 있습니다. Node.js 속도와 방대한 생태계로 인해 여전히 인기가 있는 반면, Python은 AI 기반 애플리케이션에서 탁월합니다. Go는 동시성이 높은 시스템을, 성능이 중요한 작업을 위해 Rust를 위해 등장하고 있으며, Kotlin은 Android 개발을 넘어 주목을 받고 있습니다. 노련한 백엔드 개발 회사인 Agile District는 이러한 기술을 활용하여 백엔드 스택을 비즈니스 목표에 맞게 조정합니다. 이러한 도구는 최신 기업 요구 사항을 충족하는 성능, 확장성 및 개발자 친화성의 조합을 제공합니다. 올바른 앱을 선택하면 앱이 대규모로 속도, 효율성 및 보안을 제공할 수 있습니다.\\n\\n### Agile District가 각 클라이언트에 이상적인 백엔드 스택을 선택하는 방법 [...] ## 로그인해서 콘텐츠 더보기\\n\\n무료 계정을 만들거나 로그인하여 검색을 계속하세요.\\n\\n또는\\n\\nLinkedIn이 처음이세요? 회원 가입\\n\\n가입이나 로그인을 하기 위해 계속 버튼을 클릭하면 LinkedIn 사용자약관, 개인정보 처리방침, 쿠키정책에 동의하게 됩니다.\\n\\n 본문 내용으로 가기 \\n\\n# 2025년 최고의 백엔드 기술: 앱에 적합한 스택 선택\\n\\n 신고\\n\\nAgile District \\n\\n### Agile District\\n\\n#### Driving Digital Excellence.\\n\\n발행일: 2025년 5월 28일\\n\\n+ 팔로우\\n\\n이 글은 영어에서 자동으로 기계 번역되었으며 부정확한 내용이 포함될 수 있습니다.  자세히 보기\\n\\n 원본 보기\\n\\n백엔드 기술은 앱 인터페이스 뒤에 있는 모든 기능을 지원하는 엔진입니다. 데이터베이스 관리부터 API 통합까지 백엔드는 모든 것이 원활하고 안전하게 작동하도록 보장합니다. 2025년에는 백엔드 개발의 발전으로 기업이 얼마나 빨리 확장하고 혁신할 수 있는지가 결정되고 있습니다. 선도적인 백엔드 개발 회사인 Agile District는 모듈성, 속도 및 보안을 지원하는 백엔드 프레임워크를 선택하는 것이 전략적 중요성을 강조합니다. 엔터프라이즈급 애플리케이션을 구축하든 세련된 모바일 앱을 구축하든 올바른 스택을 선택하면 장기적인 성공을 위한 기반이 마련됩니다. 백엔드 개발의 핵심은 성능, 데이터 처리 및 미래 지향적인 아키텍처에 관한 것입니다.\\n\\n### 2025년에 올바른 백엔드 스택을 선택하는 것이 그 어느 때보다 중요한 이유 [...] ### 주요 백엔드 기술의 성능, 확장성 및 보안 비교\\n\\n2025년에 백엔드 기술을 선택할 때는 성능, 확장성 및 보안에 대해 평가하는 것이 중요합니다. Node.js 뛰어난 실시간 처리를 제공하지만 CPU 바운드 작업이 부족할 수 있습니다. Python은 다재다능하고 AI 친화적이지만 컴파일된 언어보다 느립니다. Go는 동시성에서 빛을 발하여 클라우드 앱에 적합하며 Rust는 메모리 안전성과 속도를 제공합니다. Kotlin은 최신 구문과 엔터프라이즈 안정성의 균형을 유지합니다. 신뢰할 수 있는 백엔드 개발 회사인 Agile District는 효율적이고 안전한 애플리케이션을 제공하기 위해 각 프로젝트에 대해 이러한 측면을 비교합니다. 기술 스택을 비즈니스 로직에 맞추는 것은 탄력적이고 미래에 대비한 백엔드 인프라를 만드는 데 중요합니다.\\n\\n## LinkedIn 추천\\n\\n왜 Angular인가?\\n\\nPriyanshu Singh   5개월 전\\n\\nGo가 RESTful API 개발을 위한 필수 언어인 이유는 무엇입니까?\\n\\nAVA® - An Orange Education Label   9개월 전\\n\\n장대한 대결: .NET 8 vs Node.js — 2025년 최고의 백엔드 챔피언\\n\\nMuralidhar Dasari   8개월 전\\n\\n### 서버리스 아키텍처의 부상과 백엔드 개발에 미치는 영향", "score": 0.798077, "raw_content": null}, {"url": "https://scopicsoftware.com/ko/blog/backend-technologies/", "title": "10년에 사용할 상위 2024가지 백엔드 기술 및 프레임워크 - Scopic", "content": "당사의 맞춤형 솔루션이 고객이 특정 목표를 달성하는 데 어떻게 도움이 되었는지 실제 사례를 확인하세요.\\n\\n당사의 포괄적인 가이드를 통해 풍부한 지식, 업계 모범 사례 및 귀중한 통찰력을 얻으세요.\\n\\nen\\nen\\nko\\nko\\n\\n# 10년에 사용할 상위 2024가지 백엔드 기술 및 프레임워크\\n\\nby 베일리 램지 | 2024 년 7 월 9 일\\n\\n백엔드 기술\\n\\n차례\\n\\n백엔드 개발은 최신 웹 및 모바일 애플리케이션을 만드는 데 있어 중요한 구성 요소로, 애플리케이션의 원활한 작동, 성능 및 확장성을 보장합니다.  \\n\\n종종 고려됨 의 중추 맞춤형 웹 애플리케이션 개발, 삼캔드 솔루션 극대화 전에, 사용자 경험 및 드라이브 비즈니스 성장. So 성공적인 백엔드 개발을 다른 개발과 차별화하는 요소는 무엇인가? \\n\\n올바른 백엔드 기술 스택을 선택하는 것은  ...
# ⚠️ 경고: [BE] 인증 로직 구현에 대한 구조화된 응답(Tool Call)이 없습니다.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       4 from app.agents.graph import builder, recommend_graph
#       5 from app.core.log import langfuse_handler
# ----> 7 output = recommend_graph.invoke({
#       8     "current_node_type": "Task",
#       9     "node_name": "[BE] 인증 로직 구현",
#      10     "node_description": "백엔드에서 사용자 로그인을 위한 인증로직을 구현합니다."
#      11 },config={"callbacks": [langfuse_handler]})
#
# File c:\Users\SSAFY\miniforge3\envs\projectree\Lib\site-packages\langgraph\pregel\main.py:3071, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3068 chunks: list[dict[str, Any] | Any] = []
#    3069 interrupts: list[Interrupt] = []
# -> 3071 for chunk in self.stream(
#    3072     input,
#    3073     config,
#    3074     context=context,
#    3075     stream_mode=["updates", "values"]
#    3076     if stream_mode == "values"
#    3077     else stream_mode,
#    3078     print_mode=print_mode,
#    3079     output_keys=output_keys,
#    3080     interrupt_before=interrupt_before,
#    3081     interrupt_after=interrupt_after,
#    3082     durability=durability,
#    3083     **kwargs,
#    3084 ):
#    3085     if stream_mode == "values":
#    3086         if len(chunk) == 2:
#
# File c:\Users\SSAFY\miniforge3\envs\projectree\Lib\site-packages\langgraph\pregel\main.py:2656, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2646 for _ in runner.tick(
#    2647     [t for t in loop.tasks.values() if not t.writes],
#    2648     timeout=self.step_timeout,
#    (...)   2651 ):
#    2652     # emit output
#    2653     yield from _output(
#    2654         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2655     )
# -> 2656 loop.after_tick()
#    2657 # wait for checkpoint
#    2658 if durability_ == "sync":
#
# File c:\Users\SSAFY\miniforge3\envs\projectree\Lib\site-packages\langgraph\pregel\_loop.py:542, in PregelLoop.after_tick(self)
#     540 writes = [w for t in self.tasks.values() for w in t.writes]
#     541 # all tasks have finished
# --> 542 self.updated_channels = apply_writes(
#     543     self.checkpoint,
#     544     self.channels,
#     545     self.tasks.values(),
#     546     self.checkpointer_get_next_version,
#     547     self.trigger_to_nodes,
#     548 )
#     549 # produce values output
#     550 if not self.updated_channels.isdisjoint(
#     551     (self.output_keys,)
#     552     if isinstance(self.output_keys, str)
#     553     else self.output_keys
#     554 ):
#
# File c:\Users\SSAFY\miniforge3\envs\projectree\Lib\site-packages\langgraph\pregel\_algo.py:296, in apply_writes(checkpoint, channels, tasks, get_next_version, trigger_to_nodes)
#     294 for chan, vals in pending_writes_by_channel.items():
#     295     if chan in channels:
# --> 296         if channels[chan].update(vals) and next_version is not None:
#     297             checkpoint["channel_versions"][chan] = next_version
#     298             # unavailable channels can't trigger tasks, so don't add them
#
# File c:\Users\SSAFY\miniforge3\envs\projectree\Lib\site-packages\langgraph\channels\binop.py:122, in BinaryOperatorAggregate.update(self, values)
#     120         continue
#     121     if not seen_overwrite:
# --> 122         self.value = self.operator(self.value, value)
#     123 return True
#
# TypeError: can only concatenate list (not "TechList") to list

# %%
output

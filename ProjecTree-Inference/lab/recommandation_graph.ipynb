# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
from app.agents.graph import builder, recommend_graph
from app.core.log import langfuse_handler

output = recommend_graph.invoke({
    "task_type": "BackEnd",
    "node_name": "인증 로직 구현",
    "node_description": "백엔드에서 사용자 로그인을 위한 인증로직을 구현합니다."
}, config={"callbacks": [langfuse_handler]})
# Out:
# techs=[TechRecommandation(id=1, name='react-js', advantage='탁월한 성능과 유연성', disadvantage='학습 곡선이 가파름', description='사용자 인터페이스 구축에 탁월한 성능과 유연성을 제공합니다.', recommendation_score=5, tech_type='FE'), TechRecommandation(id=2, name='angular', advantage='강력한 타입 안전성', disadvantage='초기 설정이 복잡함', description='강력한 타입 안전성과 구조화된 애플리케이션을 구축할 수 있습니다.', recommendation_score=4, tech_type='FE'), TechRecommandation(id=3, name='vue.js', advantage='경량화된 프레임워크', disadvantage='대규모 프로젝트에서 성능 문제', description='경량화된 프레임워크로, 빠른 개발 속도와 쉬운 학습 곡선을 제공합니다.', recommendation_score=4, tech_type='FE')] compairson='인증 로직 구현에 적합한 프론트엔드 기술 스택 비교'
# techs=[TechRecommandation(id=1, name='spring-boot', advantage='빠른 개발, 내장된 서버, 자동 구성', disadvantage='학습 곡선, 의존성 관리', description='Spring Boot는 Spring Framework를 기반으로 한 오픈 소스 Java 프레임워크로, 웹 애플리케이션 및 마이크로서비스를 개발하기 위한 도구와 라이브러리를 제공합니다.', recommendation_score=4, tech_type='BE'), TechRecommandation(id=2, name='jwt', advantage='간단한 구현, 확장성, 보안', disadvantage='토큰 크기, 토큰 만료', description='JSON Web Token (JWT)은 클라이언트와 서버 간에 정보를 안전하게 전송하기 위한 표준화된 방법입니다. JWT는 토큰을 사용하여 사용자 인증 및 권한 부여를 처리합니다.', recommendation_score=4, tech_type='BE'), TechRecommandation(id=3, name='api-gateway', advantage='중앙 집중식 관리, 보안 강화, 성능 최적화', disadvantage='복잡성, 단일 장애 지점', description='API Gateway는 클라이언트와 마이크로서비스 간의 중개자 역할을 하는 서비스로, 요청을 라우팅하고 인증, 인증, 로깅 등의 기능을 제공합니다.', recommendation_score=4, tech_type='BE')] compairson='Spring Boot는 빠른 개발과 내장된 서버를 제공하여 백엔드 개발에 적합합니다. JWT는 토큰을 사용하여 사용자 인증 및 권한 부여를 처리하여 보안을 강화합니다. API Gateway는 클라이언트와 마이크로서비스 간의 중개자 역할을 하여 중앙 집중식 관리와 보안 강화를 제공합니다.'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       4 from app.agents.graph import builder, recommend_graph
#       5 from app.core.log import langfuse_handler
# ----> 7 output = recommend_graph.invoke({
#       8     "current_node_type": "Task",
#       9     "node_name": "인증 로직 구현",
#      10     "node_description": "백엔드에서 사용자 로그인을 위한 인증로직을 구현합니다."
#      11 }, config={"callbacks": [langfuse_handler]})
#
# File e:\miniforge3\envs\projecTree\Lib\site-packages\langgraph\pregel\main.py:3071, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3068 chunks: list[dict[str, Any] | Any] = []
#    3069 interrupts: list[Interrupt] = []
# -> 3071 for chunk in self.stream(
#    3072     input,
#    3073     config,
#    3074     context=context,
#    3075     stream_mode=["updates", "values"]
#    3076     if stream_mode == "values"
#    3077     else stream_mode,
#    3078     print_mode=print_mode,
#    3079     output_keys=output_keys,
#    3080     interrupt_before=interrupt_before,
#    3081     interrupt_after=interrupt_after,
#    3082     durability=durability,
#    3083     **kwargs,
#    3084 ):
#    3085     if stream_mode == "values":
#    3086         if len(chunk) == 2:
#
# File e:\miniforge3\envs\projecTree\Lib\site-packages\langgraph\pregel\main.py:2656, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2646 for _ in runner.tick(
#    2647     [t for t in loop.tasks.values() if not t.writes],
#    2648     timeout=self.step_timeout,
#    (...)   2651 ):
#    2652     # emit output
#    2653     yield from _output(
#    2654         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2655     )
# -> 2656 loop.after_tick()
#    2657 # wait for checkpoint
#    2658 if durability_ == "sync":
#
# File e:\miniforge3\envs\projecTree\Lib\site-packages\langgraph\pregel\_loop.py:542, in PregelLoop.after_tick(self)
#     540 writes = [w for t in self.tasks.values() for w in t.writes]
#     541 # all tasks have finished
# --> 542 self.updated_channels = apply_writes(
#     543     self.checkpoint,
#     544     self.channels,
#     545     self.tasks.values(),
#     546     self.checkpointer_get_next_version,
#     547     self.trigger_to_nodes,
#     548 )
#     549 # produce values output
#     550 if not self.updated_channels.isdisjoint(
#     551     (self.output_keys,)
#     552     if isinstance(self.output_keys, str)
#     553     else self.output_keys
#     554 ):
#
# File e:\miniforge3\envs\projecTree\Lib\site-packages\langgraph\pregel\_algo.py:296, in apply_writes(checkpoint, channels, tasks, get_next_version, trigger_to_nodes)
#     294 for chan, vals in pending_writes_by_channel.items():
#     295     if chan in channels:
# --> 296         if channels[chan].update(vals) and next_version is not None:
#     297             checkpoint["channel_versions"][chan] = next_version
#     298             # unavailable channels can't trigger tasks, so don't add them
#
# File e:\miniforge3\envs\projecTree\Lib\site-packages\langgraph\channels\binop.py:122, in BinaryOperatorAggregate.update(self, values)
#     120         continue
#     121     if not seen_overwrite:
# --> 122         self.value = self.operator(self.value, value)
#     123 return True
#
# TypeError: can only concatenate list (not "TechList") to list

# %%
output
